# %%
import torch
import string
import numpy as np
import itertools as it
from transformers import BertTokenizer, BertModel, BertConfig
import pandas as pd
from misinformation_classifier import read_data, process_docs
from scipy.spatial.distance import cosine as cossim

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# !python -m spacy download en_core_web_lg
import spacy
import en_core_web_lg
# Out:
# Collecting en_core_web_lg==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 13.2 MB/s eta 0:00:01     |█████████████████████████▊      | 665.4 MB 14.9 MB/s eta 0:00:11
# Requirement already satisfied: spacy>=2.2.2 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.40.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.22.0)
# Requirement already satisfied: thinc==7.4.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: setuptools in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (41.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.17.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.25.7)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (0.23)
# Requirement already satisfied: zipp>=0.5 in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in /Users/darius/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (7.2.0)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180940 sha256=9cb50473fe5d9b553b99947d7848092a6b7fd9bf33ab1456fd1c8b430714dcb3
#   Stored in directory: /private/var/folders/tn/2pq1hztd2lb_n9llwz1gjy2h0000gn/T/pip-ephem-wheel-cache-_gocgcng/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
class Embedding(object):
    """
    Extend this class and overide get_embedding method with whatever is used to
    generate the embedding
    """
    def get_embedding(self, sentence):
        pass

class BERTEmbedding(Embedding):

    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer

    def get_embedding(self, sentence, max_len=64):
        """
        Input formtting for BERT
        """
        encoded_dict = self.tokenizer.encode_plus(
            sentence, 
            add_special_tokens = True,    # Add '[CLS]' and '[SEP]'
            max_length = max_len,         # Pad & truncate all sentences.
            pad_to_max_length = False,
            return_attention_mask = False, # Construct attn. masks.
            return_tensors = 'pt',        # Return pytorch tensors.
        )
        
        """
        Creating word/sentence vectors
        """
        # Predict hidden states features for each layer
        with torch.no_grad():
          hidden_states = self.model(encoded_dict['input_ids'])[2]

        token_embeddings = torch.stack(hidden_states, dim=0)   # (12, batch_size, token_length, embedding_size)
        token_embeddings = torch.squeeze(token_embeddings, dim=1)
        token_embeddings = token_embeddings.permute(1,0,2)  # (token_length, 12, embedding_size (768))

        """
        Sentence vectors
        """
        token_vecs = hidden_states[-4:][0]
        sentence_embedding = torch.mean(token_vecs, dim=1)
        sentence_embedding = torch.mean(sentence_embedding, dim=0)

        return sentence_embedding.numpy()
    
class Word2Vec(Embedding):
    def __init__(self, model):
        self.model = model.load()

    def get_embedding(self, sentence):
        wordvecs = []
        for token in self.model(sentence):
            wordvecs.append(token.vector)

        vec_arr = np.array(wordvecs)
        avg_vec = np.mean(vec_arr, axis=0)
        assert len(wordvecs[0]) == avg_vec.shape[0]

        return avg_vec

# %%
config = BertConfig.from_pretrained('model_save/', output_hidden_states=True)
model = BertModel.from_pretrained('model_save/', config=config)
tokenizer = BertTokenizer.from_pretrained('model_save/')
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
embedding = BERTEmbedding(model, tokenizer)
# embedding = Word2Vec(en_core_web_lg)

# %%
remove = string.punctuation
remove = remove.replace('/', '')

with open('latest_ideas_misinformation.csv', 'r') as f:
    lines = f.readlines()
lines = [line.split('\t')[-1].strip() for line in lines[1:]]
misinformation = pd.DataFrame({'sentence': lines})
misinformation.sentence = misinformation.apply(lambda x: x.sentence.translate({ord(c): None for c in remove}), axis=1)
misinformation['embedding'] = misinformation.apply(lambda x: embedding.get_embedding(x.sentence), axis=1)
misinformation.head()
# Out:
#                                             sentence  \
# 0  gargling with bleach will prevent/cure – also ...
# 1  drinking corona beer will prevent/cure – also ...
# 2               taking acetic acid will prevent/cure
# 3                  taking steroids will prevent/cure
# 4                  taking colloidal silver will cure
#
#                                            embedding
# 0  [-0.39152414, -0.6630647, 0.34272134, -0.05833...
# 1  [-0.32701516, -0.5514859, 0.13181137, -0.17519...
# 2  [-0.32734972, -0.20340192, 0.24712618, -0.0114...
# 3  [-0.22360928, -0.2570151, 0.10327525, -0.15645...
# 4  [-0.38702664, -0.42426723, 0.11841856, 0.00288...

# %%
with open('quorona.txt', 'r') as f:
    lines = f.readlines()
lines = [line.strip() for line in lines]
df = pd.DataFrame({'sentence': lines})
df = df.sample(100)
df.sentence = df.apply(lambda x: x.sentence.translate({ord(c): None for c in remove}), axis=1)
df['embedding'] = df.apply(lambda x: embedding.get_embedding(x.sentence), axis=1)
df.head()
# Out:
#                                                sentence  \
# 3845       will coronavirus survive in high temperature
# 3362  what is coronavirus and what happens now it is...
# 1895               does coronavirus cause a sore throat
# 3808             will coronavirus end with warm weather
# 6085   how long does coronavirus live on surfaces chart
#
#                                               embedding
# 3845  [-0.12987584, -0.28084862, 0.28179958, -0.0215...
# 3362  [-0.13366845, -0.3387423, 0.07689589, -0.05812...
# 1895  [-0.18242365, -0.4832562, 0.08941638, 0.153969...
# 3808  [-0.3298868, -0.33108774, 0.52107453, 0.268209...
# 6085  [0.37919047, -0.55202806, -0.16150321, 0.05773...

# %%
def get_match(embedding):
    sims = [cossim(embedding, e) for e in misinformation.embedding]
    return '{},{}'.format(misinformation.loc[np.argmax(sims), 'sentence'], max(sims))

# %%
df['temp'] = df.apply(lambda x: get_match(x.embedding), axis=1)
df['match'] = df.apply(lambda x: x.temp.split(',')[0], axis=1)
df['score'] = df.apply(lambda x: x.temp.split(',')[1], axis=1)
df.drop(columns=['temp', 'embedding'], inplace=True)
df = df.sort_values(by=['score'], ascending=False)
df
# Out:
#                                                sentence  \
# 1873                   does coronavirus affect children
# 1167                       coronavirus medicine vaccine
# 6874                what is the cause for coronaviruses
# 6230                            influenza a coronavirus
# 4726                     coronavirus is there a vaccine
# 6244                      is coronavirus a pandemic now
# 2220                   how coronavirus effects the body
# 2649                      how the coronavirus is caused
# 3569            what states have coronavirus in the usa
# 5858              how coronavirus transmitted in humans
# 3799                     will coronavirus die in summer
# 6634                  symptoms of coronavirus in people
# 1589                 coronavirus thailand travel advice
# 3228                   ultima hora coronavirus gipuzkoa
# 3522          what is the coronavirus incubation period
# 3885                   Where do coronaviruses come from
# 1656                                 coronavirus uk map
# 6599                  symptoms of coronavirus back pain
# 1186                                   coronavirus ncbi
# 5877                       how did coronavirus happened
# 475                       corona virus type of pathogen
# 4604                         coronavirus in westchester
# 1780                         coronavirus vaccine status
# 6230  This is “fake news” invented by Trump to stren...   0.6240950226783752
# 4726  It was caused by an infected rat biting a stud...   0.6180782616138458
# 6244  This is “fake news” invented by Trump to stren...   0.6047084331512451
# 2220  Covid 19 is a normal flu and is no more danger...   0.5944984257221222
# 2649  Covid 19 is a normal flu and is no more danger...   0.5934285819530487
# 3569  Covid 19 is a normal flu and is no more danger...   0.5929408669471741
# 5858  Covid 19 is a normal flu and is no more danger...    0.587576150894165
# 3799  Covid 19 is a normal flu and is no more danger...   0.5862021148204803
# 6634  Covid 19 is a normal flu and is no more danger...   0.5839188396930695
# 1589          All human interaction needs to be stopped   0.5837195813655853
# 3228  This is “fake news” invented by Trump to stren...   0.5757498145103455
# 3522  Covid 19 is a normal flu and is no more danger...   0.5706444978713989
# 3885  Covid 19 is a normal flu and is no more danger...   0.5703994333744049
# 1656          All human interaction needs to be stopped   0.5573802292346954
# 6599        Institut Pasteur in France invented COVID19   0.5568265020847321
# 1186           Only large gatherings have to be stopped   0.5473916232585907
# 5877         rinsing your nose with saline will prevent   0.5449689328670502
# 475   This is “fake news” invented by Trump to stren...   0.5422976315021515
# 4604  This is “fake news” invented by Trump to stren...   0.5415459871292114
# 1780           Only large gatherings have to be stopped   0.5388090014457703
# 3804  It was caused by an infected rat biting a stud...   0.5332788228988647
# 3237  Covid 19 is a normal flu and is no more danger...   0.5319922566413879
# 7205  spraying normal drinking alcohol on body will ...    0.529199481010437
# 1547  Covid 19 is a normal flu and is no more danger...   0.5249744057655334
# 6921  It was caused by an infected rat biting a stud...   0.5235293209552765
# 725   This is “fake news” invented by Trump to stren...   0.5225281119346619
# 6968  It was caused by an infected rat biting a stud...   0.5218442678451538
# 6751  It leaked from the Wuhan Institute of Virology...   0.5216152966022491
# 5748  Covid 19 is a normal flu and is no more danger...   0.5205978453159332
# 1794           Only large gatherings have to be stopped   0.5194971859455109
# 6795  It was caused by an infected rat biting a stud...   0.5178989768028259
# 982   This is “fake news” invented by Trump to stren...    0.514674961566925
# 1193           Only large gatherings have to be stopped   0.5139737725257874
# 6185  It was caused by an infected rat biting a stud...   0.5083475410938263
# 5066          All human interaction needs to be stopped   0.5065255463123322
# 3918  Covid 19 is a normal flu and is no more danger...   0.5040272176265717
# 6589  Covid 19 is a normal flu and is no more danger...     0.50364750623703
# 3362        Institut Pasteur in France invented COVID19   0.5013706684112549
# 1796          All human interaction needs to be stopped   0.5004142224788666
# 6865  It leaked from the Wuhan Institute of Virology...   0.4943835139274597
# 4940  Covid 19 is a normal flu and is no more danger...  0.49410492181777954
# 1731           Only large gatherings have to be stopped   0.4929376244544983
# 6637          All human interaction needs to be stopped   0.4922904968261719
# 1636  Covid 19 is a normal flu and is no more danger...  0.49105530977249146
# 6286        Institut Pasteur in France invented COVID19    0.489591121673584
# 6966         rinsing your nose with saline will prevent  0.48890262842178345
# 5894  Covid 19 is a normal flu and is no more danger...   0.4869961738586426
# 5091  It was caused by an infected rat biting a stud...   0.4860595464706421
# 3777  It leaked from the Wuhan Institute of Virology...   0.4857954978942871
# 1236  Covid 19 is a normal flu and is no more danger...  0.48501646518707275
# 440   Only people who have tested positive need to s...   0.4836149215698242
# 3216        Institut Pasteur in France invented COVID19   0.4830250144004822
# 1968  Covid 19 is a normal flu and is no more danger...  0.48030292987823486
# 1087  It was caused by an infected rat biting a stud...   0.4775776267051697
# 5931  It was caused by an infected rat biting a stud...   0.4772517681121826
# 6160  It leaked from the Wuhan Institute of Virology...   0.4765651226043701
# 6153  It was caused by an infected rat biting a stud...   0.4717339873313904
# 6806  Social distancing will lead to dramatic immedi...   0.4711737036705017
# 1499          All human interaction needs to be stopped  0.47007983922958374
# 7008  Riots in London due to unavailability of food ...   0.4695942997932434
# 4963  you have to be with someone for 10 minutes to ...   0.4695768356323242
# 6288        Institut Pasteur in France invented COVID19  0.46909552812576294
# 3952  This is “fake news” invented by Trump to stren...   0.4690926671028137
# 6005  Riots in London due to unavailability of food ...   0.4669194221496582
# 7259                                Africans are immune   0.4651328921318054
# 7178           Only large gatherings have to be stopped  0.46434926986694336
# 1376                             Vegetarians are immune  0.46290236711502075
# 6569  It was caused by an infected rat biting a stud...   0.4628680348396301
# 7230  People with typeA blood are more prone to get ...  0.46235036849975586
# 6214  It was caused by an infected rat biting a stud...   0.4615139961242676
# 64    It was caused by an infected rat biting a stud...   0.4611145853996277
# 6355         rinsing your nose with saline will prevent   0.4602327346801758
# 2361  Covid 19 is a normal flu and is no more danger...   0.4601626396179199
# 1895  It leaked from the Wuhan Institute of Virology...  0.46004045009613037
# 2808  It leaked from the Wuhan Institute of Virology...  0.45095282793045044
# 6305  It leaked from the Wuhan Institute of Virology...  0.45095282793045044
# 2381  It was caused by an infected rat biting a stud...   0.4496312737464905
# 6600          All human interaction needs to be stopped   0.4454801082611084
# 2682                        Shaving your beard prevents   0.4434138536453247
# 4667  Only people who have tested positive need to s...  0.44328057765960693
# 347          rinsing your nose with saline will prevent   0.4415932893753052
# 6010  It was caused by an infected rat biting a stud...   0.4376987814903259
# 1314          All human interaction needs to be stopped   0.4364812970161438
# 6085  Riots in London due to unavailability of food ...  0.43389689922332764
# 4713  It was caused by an infected rat biting a stud...  0.43288445472717285
# 3731         rinsing your nose with saline will prevent  0.42811983823776245
# 3808                                Africans are immune   0.4242486357688904
# 2136  Covid 19 is a normal flu and is no more danger...   0.4224308133125305
# 2414          All human interaction needs to be stopped  0.42198848724365234
# 5897  Riots in London due to unavailability of food ...   0.4131307005882263
# 5534  It leaked from the Wuhan Institute of Virology...  0.40809983015060425
# 1956                                Africans are immune   0.4042527675628662
# 3845  It was caused by an infected rat biting a stud...  0.39880526065826416
# 221                                 Africans are immune   0.3966628313064575
# 182   Riots in London due to unavailability of food ...   0.3965069055557251
# 3988  Riots in London due to unavailability of food ...   0.3955610394477844
# 94    It was caused by an infected rat biting a stud...  0.38779622316360474
